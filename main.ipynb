# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import joblib
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from features_flattener import split_sessions, flatten_features, get_top_digraphs,clean_feature_names

# %%
user_files = {
    "advait": "data/advait_keystrokes.csv",
    "chetan": "data/chetan_keystrokes.csv",
    "gayaa": "data/gayatri_keystrokes.csv",
    "purva": "data/purva_keystrokes.csv",
    "siddhant": "data/siddhant_keystrokes.csv",
}

# %%
top_digraphs = get_top_digraphs(user_files.values(), N=20)
top_digraphs
# Out:
# [('e', 'Key.space'),
#  ('t', 'Key.space'),
#  ('n', 'Key.space'),
#  ('Key.space', 'w'),
#  ('Key.space', 's'),
#  ('Key.space', 't'),
#  ('e', 'r'),
#  ('t', 'h'),
#  ('d', 'Key.space'),
#  ('Key.space', 'a'),
#  ('a', 'n'),
#  ('r', 'Key.space'),
#  ('Key.space', 'o'),
#  ('h', 'e'),
#  ('i', 'n'),
#  ('Key.backspace', 'Key.backspace'),
#  ('Key.space', 'h'),
#  ('o', 'u'),
#  ('y', 'Key.space'),
#  ('Key.space', 'm')]

# %%
rows = []
for user, file in user_files.items():
    sessions = split_sessions(file, session_size=100)
    for sess in sessions:
        row = flatten_features(sess, user, top_digraphs)
        rows.append(row)

# %%
df = pd.DataFrame(rows).fillna(0)
df.to_csv("data/processed_data.csv")

# %%
print("dd_entropy" in df.columns)
print(f"shape: {df.shape}")
# Out:
# True
# shape: (1059, 85)

# %%
# Correlation matrix
corr_matrix = df.drop("label", axis=1).corr()

print(corr_matrix.shape)
corr_matrix.head()
# Out:
# (84, 84)
#                   hold_r  hold_Key.space    hold_l    hold_i    hold_k  \
# hold_r          1.000000        0.306199  0.233637  0.278610  0.051630
# hold_Key.space  0.306199        1.000000  0.182634  0.201775  0.073650
# hold_l          0.233637        0.182634  1.000000  0.363054  0.129669
# hold_i          0.278610        0.201775  0.363054  1.000000  0.152547
# hold_k          0.051630        0.073650  0.129669  0.152547  1.000000
#
#                   hold_e    hold_g    hold_t    hold_h    hold_c  ...  \
# hold_r          0.565939  0.220127  0.459648  0.238275  0.248880  ...
# hold_Key.space  0.462947  0.183083  0.372363  0.199918  0.207365  ...
# hold_l          0.400195  0.065141  0.305552  0.339166  0.242211  ...
# hold_i          0.463656  0.237731  0.347205  0.339219  0.180222  ...
# hold_k          0.113558 -0.064255  0.113154  0.096390  0.038116  ...
#
#                   hold_z    hold_:    hold_(  hold_Key.shift_r  \
# ...

# %%
threshold = 0.8

high_corr_pairs = []

for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        
        corr_value = corr_matrix.iloc[i, j]
        
        if abs(corr_value) > threshold:
            feature1 = corr_matrix.columns[i]
            feature2 = corr_matrix.columns[j]
            
            high_corr_pairs.append((feature1, feature2, corr_value))

for f1, f2, c in high_corr_pairs[:20]:
    print(f"{f1}  ->  {f2} : {c:.2f}")
# Out:
# dd_std  ->  dd_max : 0.97
# hold_Key.esc  ->  hold_Key.tab : 0.82
# hold_Key.ctrl_l  ->  hold_ : 0.81
# hold_Key.right  ->  hold_Key.shift : 0.96
# hold_Key.down  ->  hold_Key.up : 0.97
# hold_:  ->  hold_( : 1.00
# hold_:  ->  hold_Key.shift_r : 1.00
# hold_(  ->  hold_Key.shift_r : 1.00
# hold_Key.print_screen  ->  hold_Key.delete : 1.00

# %%
plt.figure(figsize=(12,10))

sns.heatmap(
    corr_matrix,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Matrix of Keystroke Features")
plt.show()
# Out:
# d:\AIDS Sem 5\ML\CP\Keystroke-Rhythm-Based-User-Verifier\.venv\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 20 () missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# d:\AIDS Sem 5\ML\CP\Keystroke-Rhythm-Based-User-Verifier\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def custom_pca_fit(X):

    X = np.array(X)

    mean_vec = np.mean(X, axis=0)
    X_centered = X - mean_vec

    cov_matrix = np.cov(X_centered, rowvar=False)

    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

    sorted_idx = np.argsort(eigenvalues)[::-1]

    eigenvalues = eigenvalues[sorted_idx]
    eigenvectors = eigenvectors[:, sorted_idx]

    return mean_vec, eigenvectors, eigenvalues


def custom_pca_transform(X, mean_vec, eigenvectors, n_components):

    X = np.array(X)

    X_centered = X - mean_vec

    components = eigenvectors[:, :n_components]

    X_reduced = np.dot(X_centered, components)

    return X_reduced

# %%
X = clean_feature_names(df.drop("label", axis=1)).astype(np.float32)
y = df["label"]

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Shuffle dataset (important for fair folds)
indices = np.arange(len(X))
np.random.seed(42)
np.random.shuffle(indices)

X_shuffled = X.iloc[indices].reset_index(drop=True)
y_shuffled = y_encoded[indices]

# %%
K = 5
fold_size = len(X_shuffled) // K

results = {
    "XGBoost": [],
    "RandomForest": [],
    "Ensemble": []
}

# %%
for i in range(K):

    start = i * fold_size
    end = (i + 1) * fold_size if i != K-1 else len(X_shuffled)

    X_test_fold = X_shuffled.iloc[start:end]
    y_test_fold = y_shuffled[start:end]

    X_train_fold = pd.concat([X_shuffled.iloc[:start], X_shuffled.iloc[end:]])
    y_train_fold = np.concatenate([y_shuffled[:start], y_shuffled[end:]])

    # =========================
    # 1️⃣ XGBoost
    # =========================
    xgb_model = XGBClassifier(
        eval_metric='mlogloss',
        n_estimators=300,
        max_depth=6,
        learning_rate=0.05
    )

    xgb_model.fit(X_train_fold.values, y_train_fold)
    y_pred = xgb_model.predict(X_test_fold.values)
    results["XGBoost"].append(accuracy_score(y_test_fold, y_pred))


    # =========================
    # 2️⃣ Random Forest
    # =========================
    rf_model = RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        random_state=42
    )

    rf_model.fit(X_train_fold.values, y_train_fold)
    y_pred = rf_model.predict(X_test_fold.values)
    results["RandomForest"].append(accuracy_score(y_test_fold, y_pred))


    # =========================
    # 3️⃣ Ensemble (XGB + RF + SVM)
    # =========================
    svm_model = SVC(probability=True)

    ensemble_model = VotingClassifier(
        estimators=[
            ('xgb', xgb_model),
            ('rf', rf_model),
            ('svm', svm_model)
        ],
        voting='soft'
    )

    ensemble_model.fit(X_train_fold.values, y_train_fold)
    y_pred = ensemble_model.predict(X_test_fold.values)
    results["Ensemble"].append(accuracy_score(y_test_fold, y_pred))


    print(f"\nFold {i+1} Results:")
    print(f"XGBoost: {results['XGBoost'][-1]:.4f}")
    print(f"RandomForest: {results['RandomForest'][-1]:.4f}")
    print(f"Ensemble: {results['Ensemble'][-1]:.4f}")
# Out:
# Fold 1 Results:
# XGBoost: 0.9194
# RandomForest: 0.9289
# Ensemble: 0.9242
#
# Fold 2 Results:
# XGBoost: 0.9526
# RandomForest: 0.9431
# Ensemble: 0.9526
#
# Fold 3 Results:
# XGBoost: 0.9336
# RandomForest: 0.8957
# Ensemble: 0.9100
#
# Fold 4 Results:
# XGBoost: 0.9289
# RandomForest: 0.9289
# Ensemble: 0.9289
#
# Fold 5 Results:
# XGBoost: 0.9395
# RandomForest: 0.9302
# Ensemble: 0.9302

# %%
print("\n===== FINAL RESULTS =====")

for model_name, scores in results.items():
    print(f"{model_name}:")
    print(f"  Avg Accuracy: {np.mean(scores):.4f}")
    print(f"  Std Dev: {np.std(scores):.4f}")
# Out:
# ===== FINAL RESULTS =====
# XGBoost:
#   Avg Accuracy: 0.9348
#   Std Dev: 0.0111
# RandomForest:
#   Avg Accuracy: 0.9254
#   Std Dev: 0.0158
# Ensemble:
#   Avg Accuracy: 0.9292
#   Std Dev: 0.0137

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded,
    test_size=0.18,
    random_state=42,
    stratify=y_encoded
)

# %%
mean_vec, eigenvectors, eigenvalues = custom_pca_fit(X_train)

X_train_pca = custom_pca_transform(X_train, mean_vec, eigenvectors, 66)
X_test_pca = custom_pca_transform(X_test, mean_vec, eigenvectors, 66)

X_train_pca.shape
# Out:
# (868, 66)

# %%
model = XGBClassifier(
    eval_metric='mlogloss',
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05
)

model.fit(X_train.values, y_train)

y_pred = model.predict(X_test.values)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9476439790575916
# Accuracy: 0.9476439790575916

# %%
total_variance = np.sum(eigenvalues)

explained_variance = eigenvalues / total_variance

print("Explained variance first 10 PCs:")
print(explained_variance[:10])
# Out:
# Explained variance first 10 PCs:
# [0.41608353 0.09757366 0.05105094 0.04530621 0.04010503 0.03917377
#  0.03419625 0.03278933 0.02986035 0.02524018]

# %%
plt.figure(figsize=(8,5))
plt.plot(np.cumsum(explained_variance))
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Variance Explained")
plt.title("PCA Variance Explained")
plt.show()

# %%
importance = pd.Series(
    model.feature_importances_,
    index=X.columns
)

importance = importance.sort_values(ascending=False)

print(importance.head(20))
# Out:
# hold_                            0.120121
# hold_t                            0.074575
# hold_Key_ctrl_l                   0.066281
# dd_Key_backspace_Key_backspace    0.055694
# hold_Key_enter                    0.055198
# dd_mean                           0.050284
# hold_n                            0.034276
# hold_Key_backspace                0.033613
# hold_o                            0.032845
# hold_p                            0.031080
# hold_Key_space                    0.030471
# hold_Key_esc                      0.027707
# hold_b                            0.024607
# hold_h                            0.023868
# hold_e                            0.021917
# hold_=                            0.020749
# hold_Key_alt_l                    0.016949
# hold_l                            0.015849
# dd_e_r                            0.012868
# dd_min                            0.012416
# dtype: float32

# %%
top_features = importance.head(15)

plt.figure(figsize=(10,6))
top_features.plot(kind="barh")
plt.gca().invert_yaxis()

plt.title("Top 15 Most Important Keystroke Features")
plt.xlabel("Importance Score")

plt.show()
# Out:
# d:\AIDS Sem 5\ML\CP\Keystroke-Rhythm-Based-User-Verifier\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 18 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
joblib.dump(mean_vec, "models/pca_mean.pkl")
joblib.dump(eigenvectors, "models/pca_vectors.pkl")
joblib.dump(model, "models/xgb_keystroke_model.pkl")
joblib.dump(le, "models/label_encoder.pkl")
joblib.dump(top_digraphs, "models/top_digraphs.pkl")
feature_names = list(X.columns)
joblib.dump(feature_names, "models/feature_names.pkl")
# Out:
# ['models/feature_names.pkl']

# %%
probs = model.predict_proba(X_test.values)

# %%
import random

threshold = 0.6

false_accept = 0
false_reject = 0
genuine_total = 0
impostor_total = 0

num_users = len(le.classes_)

for i in range(len(y_test)):

    actual_user = y_test[i]

    # Simulate login attempt
    if random.random() < 0.5:
        # Genuine attempt
        claimed_user = actual_user
        is_genuine = True
        genuine_total += 1
    else:
        # Impostor attempt
        claimed_user = random.choice(
            [u for u in range(num_users) if u != actual_user]
        )
        is_genuine = False
        impostor_total += 1

    confidence = probs[i][claimed_user]

    # Decision
    if confidence >= threshold:
        # ACCEPT
        if not is_genuine:
            false_accept += 1
    else:
        # REJECT
        if is_genuine:
            false_reject += 1

# Final metrics
FAR = false_accept / impostor_total if impostor_total != 0 else 0
FRR = false_reject / genuine_total if genuine_total != 0 else 0

print("\n===== BIOMETRIC EVALUATION =====")
print(f"Threshold: {threshold}")
print(f"FAR (False Acceptance Rate): {FAR:.4f}")
print(f"FRR (False Rejection Rate): {FRR:.4f}")
# Out:
# ===== BIOMETRIC EVALUATION =====
# Threshold: 0.6
# FAR (False Acceptance Rate): 0.0000
# FRR (False Rejection Rate): 0.0900

# %% [markdown]
# # Keystroke Rhythm-Based User Verifier: Project Documentation
#
# ## **1. Overview**
# This project aims to identify users based on their typing patterns (keystroke dynamics). Raw keystroke logs are processed, features are extracted, and a machine learning model is trained to classify users.
#
# ---
#
# ## **2. Data Processing Pipeline**
#
# ### **A. Raw Data Collection**
# - Keystroke logs are collected for each user in CSV format.
# - Each log records key events (press/release), timestamps, and key names.
#
# ### **B. Session Splitting**
# - Logs are split into sessions of 100 keystrokes.
# - Purpose: Increases dataset size and captures variability in user behavior.
#
# ### **C. Feature Extraction**
# - For each session, features are extracted:
#   - **Hold times:** How long each key is pressed.
#   - **Digraph durations (dd_times):** Time between consecutive key presses.
# - Outliers in timings are removed using Z-score filtering.
#
# ### **D. Feature Flattening & Aggregation**
# - Features are aggregated (mean, std, min, max, entropy) and flattened into a single row per session.
# - Top-N most frequent digraphs are selected and their average timings are included as features.
#
# ### **E. Scaling & Cleaning**
# - All numeric features are scaled to [0, 1] using Min-Max scaling.
# - Feature names are cleaned for compatibility.
#
# ### **F. Label Encoding**
# - User names are converted to numeric labels for classification.
#
# ### **G. Train-Test Split**
# - Data is split into training and test sets (stratified by user).
#
# ---
#
# ## **3. Exploratory Analysis**
#
# ### **A. Top Digraphs**
# Most common digraphs (key pairs) across all users:

# %%
[('e', 'Key.space'),
 ('t', 'Key.space'),
 ('n', 'Key.space'),
 ('Key.space', 'w'),
 ('Key.space', 's'),
 ('Key.space', 't'),
 ('e', 'r'),
 ('t', 'h'),
 ('d', 'Key.space'),
 ('Key.space', 'a'),
 ('a', 'n'),
 ('r', 'Key.space'),
 ('Key.space', 'o'),
 ('h', 'e'),
 ('i', 'n'),
 ('Key.backspace', 'Key.backspace'),
 ('Key.space', 'h'),
 ('o', 'u'),
 ('y', 'Key.space'),
 ('Key.space', 'm')]
# Out:
# [('e', 'Key.space'),
#  ('t', 'Key.space'),
#  ('n', 'Key.space'),
#  ('Key.space', 'w'),
#  ('Key.space', 's'),
#  ('Key.space', 't'),
#  ('e', 'r'),
#  ('t', 'h'),
#  ('d', 'Key.space'),
#  ('Key.space', 'a'),
#  ('a', 'n'),
#  ('r', 'Key.space'),
#  ('Key.space', 'o'),
#  ('h', 'e'),
#  ('i', 'n'),
#  ('Key.backspace', 'Key.backspace'),
#  ('Key.space', 'h'),
#  ('o', 'u'),
#  ('y', 'Key.space'),
#  ('Key.space', 'm')]

# %% [markdown]
# These are used as features, capturing user-specific typing patterns.
#
# ---
#
# ### **B. Correlation Matrix**
# - Shape: (84, 84)
# - Shows pairwise correlations between all features.
# - Highly correlated pairs (examples):
#   - `dd_std` ↔ `dd_max`: 0.97
#   - `hold_Key.esc` ↔ `hold_Key.tab`: 0.82
#   - `hold_Key.ctrl_l` ↔ `hold_`: 0.81
#   - `hold_Key.right` ↔ `hold_Key.shift`: 0.96
#   - `hold_Key.down` ↔ `hold_Key.up`: 0.97
#   - `hold_:` ↔ `hold_(`: 1.00
#   - `hold_:` ↔ `hold_Key.shift_r`: 1.00
#   - `hold_(` ↔ `hold_Key.shift_r`: 1.00
#   - `hold_Key.print_screen` ↔ `hold_Key.delete`: 1.00
#
# **Purpose:**
# - Identifies redundant features.
# - Helps in feature selection and dimensionality reduction.
#
# ---
#
# ### **C. PCA (Principal Component Analysis)**
# - Used to reduce dimensionality and visualize variance explained.
# - Cumulative variance explained:
#   - First 10 PCs: [0.416, 0.098, 0.051, 0.045, 0.040, 0.039, 0.034, 0.033, 0.030, 0.025]
# - Most variance is captured in the first few components, but using PCA for classification led to a drop in accuracy (see below).
#
# ---
#
# ### **D. Feature Importance (XGBoost)**
# Top 15 most important features:

# %%
hold_                            0.136
hold_Key_ctrl_l                   0.081
hold_t                            0.073
hold_Key_enter                    0.060
dd_Key_backspace_Key_backspace    0.050
dd_mean                           0.044
hold_p                            0.035
hold_o                            0.033
hold_Key_backspace                0.033
hold_n                            0.031
hold_Key_space                    0.026
hold_e                            0.024
hold_=                            0.023
hold_Key_esc                      0.022
hold_b                            0.022
# Out:
#   Cell In[70], line 1
#     hold_                            0.136
#          ^
# SyntaxError: invalid non-printable character U+0012

# %% [markdown]
# **Purpose:**
# - Shows which features are most useful for distinguishing users.
#
# ---
#
# ## **4. Model Training & Results**
#
# - **Classifier:** XGBoost
# - **Accuracy:** 0.9476 (without PCA)
# - **PCA:** Applying PCA reduced accuracy, as tree-based models like XGBoost perform better with original features.
#
# ---
#
# ## **5. Outputs Generated**
#
# - **Processed Data:** processed_data.csv
# - **Top Digraphs:** List of most frequent digraphs
# - **Correlation Matrix:** (84, 84) matrix, visualized as a heatmap
# - **Feature Importance:** Bar plot of top features
# - **Model Artifacts:** Saved model, PCA components, label encoder, feature names
#
# ---
#
# ## **6. Key Insights**
#
# - **Preprocessing** (session splitting, feature extraction, scaling, outlier removal) is crucial for converting raw keystroke logs into meaningful, machine-learning-ready data.
# - **Feature engineering** (digraphs, hold times, entropy) captures unique user typing patterns.
# - **Correlation analysis** helps identify redundant features.
# - **PCA** is useful for visualization and dimensionality reduction, but not always for classification with tree-based models.
# - **Feature importance** guides further feature selection and model improvement.
# - **Model accuracy** is high, showing the effectiveness of the chosen features and preprocessing steps.
#
# ---
#
# ## **7. Visual Outputs**
#
# - **Correlation Matrix Heatmap:** Shows feature relationships.
# - **PCA Variance Explained Plot:** Shows how much variance is captured by each principal component.
# - **Feature Importance Bar Plot:** Highlights the most discriminative features.
#
# ---
#
# ## **8. Conclusion**
#
# This pipeline efficiently transforms raw keystroke data into structured features, enabling accurate user classification. The combination of domain-specific feature engineering and robust preprocessing is key to the model’s success.
#
# ---
